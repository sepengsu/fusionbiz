# %%
import pandas as pd
with open('./data/machine_data.txt') as f:
    lines = f.readlines()
data = [line.strip().split('\t') for line in lines]
df = pd.DataFrame(data[1:], columns=data[0])
print(df.columns)
df
# Out:
# Index(['Year', 'Month', 'Day', 'Hour', 'Minute', 'operation'], dtype='object')
#      Year Month Day Hour Minute                 operation
# 0    2021     1  29    1     14                     error
# 1    2021     1  29    1     14                   stopped
# 2    2021     1  29    1     15                 operating
# 3    2021     1  29    1     15                     error
# 4    2021     1  29    1     15                   stopped
# ..    ...   ...  ..  ...    ...                       ...
# 197  2021     1  30   15     49                   stopped
# 198  2021     1  30   15     50                 operating
# 199  2021     1  30   15     50                   stopped
# 200  2021     1  30   15     51                     error
# 201  2021     1  30   15     51  stopped during operating
#
# [202 rows x 6 columns]

# %%
import os
from pathlib import Path

# 데이터 파일들이 있는 폴더 경로
input_folder = Path('./data')
output_folder = Path("./kor_logs")
output_folder.mkdir(exist_ok=True)

# 전처리 함수
def create_sentence(row):
    date = row['Day']
    month = row['Month']
    year = row['Year']
    hour = row['Hour']
    minute = row['Minute']
    operation = row['operation']
    time = f"{year}년 {month}월 {date}일 {hour}시 {minute}분"
    if operation == "error":
        return f"{time}에 기계에서 오류가 발생했습니다."
    elif operation == "stopped":
        return f"{time}에 기계가 정지되었습니다."
    elif operation == "operating":
        return f"{time}에 기계가 정상적으로 작동 중입니다."
    else:
        return f"{time}에 기계 상태가 '{operation}'로 기록되었습니다."

# 처리할 파일 리스트 (simulated log들만 대상으로)
files_to_process = sorted(input_folder.glob("*.txt"))
output_files = []

# 각 파일에 대해 처리
for file_path in files_to_process:
    df = pd.read_csv(file_path, sep="\t")
    df['Sentence'] = df.apply(create_sentence, axis=1)

    out_name = file_path.stem + "_kor.txt"
    out_path = output_folder / out_name
    with open(out_path, "w", encoding="utf-8") as f:
        for line in df['Sentence']:
            f.write(line + "\n")
    output_files.append(str(out_path))

output_files
# Out:
# ['kor_logs\\machine_data_kor.txt',
#  'kor_logs\\machine_data_simulated_1_kor.txt',
#  'kor_logs\\machine_data_simulated_2_kor.txt',
#  'kor_logs\\machine_data_simulated_3_kor.txt']

# %%
from reportlab.pdfgen import canvas
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.lib.pagesizes import A4
from pathlib import Path

# 폰트 등록
pdfmetrics.registerFont(TTFont('NanumGothic', './utils/NanumGothic.ttf'))

# kor_logs 내 txt 파일 PDF로 하나씩 변환
input_dir = Path("./kor_logs")
output_dir = Path("./kor_pdfs")
output_dir.mkdir(exist_ok=True)

for txt_file in input_dir.glob("*.txt"):
    pdf_path = output_dir / (txt_file.stem + ".pdf")
    c = canvas.Canvas(str(pdf_path), pagesize=A4)
    c.setFont("NanumGothic", 12)
    width, height = A4
    y = height - 40

    with open(txt_file, "r", encoding="utf-8") as f:
        for line in f:
            c.drawString(40, y, line.strip())
            y -= 15
            if y < 40:
                c.showPage()
                c.setFont("NanumGothic", 12)
                y = height - 40

    c.save()
    print(f"✅ 생성 완료: {pdf_path}")
# Out:
# ---------------------------------------------------------------------------
# TTFError                                  Traceback (most recent call last)
# Cell In[7], line 8
#       5 from pathlib import Path
#       7 # 폰트 등록
# ----> 8 pdfmetrics.registerFont(TTFont('NanumGothic', './utils/NanumGothic.ttf'))
#      10 # kor_logs 내 txt 파일 PDF로 하나씩 변환
#      11 input_dir = Path("./kor_logs")
#
# File c:\Users\na062\Desktop\biz\venv\Lib\site-packages\reportlab\pdfbase\ttfonts.py:1207, in TTFont.__init__(self, name, filename, validate, subfontIndex, asciiReadable, shapable)
#    1201 """Loads a TrueType font from filename.
#    1202
#    1203 If validate is set to a false values, skips checksum validation.  This
#    1204 can save time, especially if the font is large.
#    1205 """
#    1206 self.fontName = name
# -> 1207 self.face = TTFontFace(filename, validate=validate, subfontIndex=subfontIndex)
#    1208 self.encoding = TTEncoding()
#    1209 from weakref import WeakKeyDictionary
#
# File c:\Users\na062\Desktop\biz\venv\Lib\site-packages\reportlab\pdfbase\ttfonts.py:1088, in TTFontFace.__init__(self, filename, validate, subfontIndex)
#    1086 "Loads a TrueType font from filename."
#    1087 pdfmetrics.TypeFace.__init__(self, None)
# -> 1088 TTFontFile.__init__(self, filename, validate=validate, subfontIndex=subfontIndex)
#
# File c:\Users\na062\Desktop\biz\venv\Lib\site-packages\reportlab\pdfbase\ttfonts.py:447, in TTFontFile.__init__(self, file, charInfo, validate, subfontIndex)
#     445         self.__dict__.update(__dict__)
#     446 else:
# --> 447     TTFontParser.__init__(self, file, validate=validate,subfontIndex=subfontIndex)
#     448     self.extractInfo(charInfo)
#
# File c:\Users\na062\Desktop\biz\venv\Lib\site-packages\reportlab\pdfbase\ttfonts.py:184, in TTFontParser.__init__(self, file, validate, subfontIndex)
#     182 self.validate = validate
#     183 self.readFile(file)
# --> 184 isCollection = self.readHeader()
#     185 if isCollection:
#     186     self.readTTCHeader()
#
# File c:\Users\na062\Desktop\biz\venv\Lib\site-packages\reportlab\pdfbase\ttfonts.py:250, in TTFontParser.readHeader(self)
#     247     raise TTFError('%s file "%s": postscript outlines are not supported'%(self.fileKind,self.filename))
#     249 if version not in self.ttfVersions:
# --> 250     raise TTFError('Not a recognized TrueType font: version=0x%8.8X' % version)
#     251 return version==self.ttfVersions[-1]
#
# TTFError: Not a recognized TrueType font: version=0x1F8B0800
